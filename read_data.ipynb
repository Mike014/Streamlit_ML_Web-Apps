# %%
! pip install pandas

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
file = open("steam_games.csv", "r")
df=pd.read_csv(file)
print(df)
file.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71429 entries, 0 to 71428
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   steam_appid          71429 non-null  int64
#  1   name                 71429 non-null  object
#  2   developers           71429 non-null  object
#  3   publishers           71429 non-null  object
#  4   categories           71429 non-null  object
#  5   genres               71429 non-null  object
#  6   required_age         71429 non-null  int64
#  7   n_achievements       71429 non-null  int64
#  8   platforms            71429 non-null  object
#  9   is_released          71429 non-null  bool
#  10  release_date         71429 non-null  object
#  11  additional_content   71429 non-null  object
#  12  total_reviews        71429 non-null  int64
#  13  total_positive       71429 non-null  int64
#  14  total_negative       71429 non-null  int64
# ...

# %%
df.sample(5)
# Out:
#        steam_appid                                name  \
# 23525       355380                Perfection of Wisdom
# 65984       633080                Relic Hunters Legend
# 15154      1927720  Monument Valley: Panoramic Edition
# 36913      1150390                          Steel Rain
# 10009       971210                        ChronoBreach
#
#                            developers                      publishers  \
# 23525      ['14Dimension Enterprise']      ['14Dimension Enterprise']
# 65984                 ['Rogue Snail']                 ['Rogue Snail']
# 15154                 ['ustwo games']                 ['ustwo games']
# 36913  ['Ronis Vision entertainment']  ['Ronis Vision entertainment']
# 10009                ['UpsilonGames']                ['UpsilonGames']
#
#                                               categories  \
# 23525  ['Single-player', 'Multi-player', 'Family Shar...
# 65984  ['Single-player', 'Multi-player', 'Co-op', 'On...
# ...

# %%
cdf = df[['steam_appid','name','developers','categories','genres','required_age','price_initial (USD)','total_reviews','positive_percentual']]
cdf.sample(9)
# Out:
#        steam_appid                                        name  \
# 27104      2306030                               EBOLA VILLAGE
# 20576      1480930                                Monkey Split
# 64535      3187030                        Satisfactory Modeler
# 41743      1719130                              The Ghost Cage
# 50231       672970                 Swords and Sandals Medieval
# 8931       1008890                               JetBall Arena
# 57735      3003120                                  Zombiehood
# 16525      1871790                                   Bad Faith
# 46946      2355010  Betrayal of Blood: a Strength & Virtue RPG
#
#                          developers  \
# 27104        ['indie_games_studio']
# 20576              ['Nerd Monkeys']
# 64535               ['David Price']
# 41743                ['SeaPhoenix']
# 50231     ['Whiskeybarrel Studios']
# 8931                     ['B Rees']
# 57735                   ['NLB.DEV']
# 16525                      ['Mado']
# ...

# %%
print(df.describe())
# Out:
#         steam_appid  required_age  n_achievements  total_reviews  \
# count  7.142900e+04  71429.000000    71429.000000   7.142900e+04
# mean   1.613700e+06      2.573227       16.079478   4.102497e+02
# std    8.625559e+05     13.591997      138.084319   8.389934e+03
# min    7.300000e+02      0.000000        0.000000   0.000000e+00
# 25%    9.296400e+05      0.000000        0.000000   0.000000e+00
# 50%    1.533470e+06      0.000000        0.000000   2.000000e+00
# 75%    2.383530e+06      0.000000       16.000000   1.900000e+01
# max    3.430140e+06     97.000000     9821.000000   1.279700e+06
#
#        total_positive  total_negative  review_score  positive_percentual  \
# count    7.142900e+04    71429.000000  71429.000000         71429.000000
# mean     3.602238e+02       50.025886      2.192849            46.113290
# std      7.409672e+03     1171.055349      3.175885            41.961702
# min      0.000000e+00        0.000000      0.000000             0.000000
# ...

# %%
import streamlit as st
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve
from sklearn.metrics import precision_score, recall_score 

# Test if the libraries are correct
print(st.__version__)
print(pd.__version__)
print(np.__version__)
print(sk.__version__)

def main():
    st.title("Binary Classification Web App")
    st.sidebar.title("Binary Classification Web App")
    st.markdown("Which game of 2025, on STEAM will be considered the best?")
    st.sidebar.markdown("Which game of 2025, on STEAM will be considered the best?")

    @st.cache_data(persist=True)
    def load_data():
        df = pd.read_csv("steam_games.csv")
        label = LabelEncoder()
        for col in df.columns:
            df[col] = label.fit_transform(df[col])
        return df

    @st.cache_data(persist=True)
    def split(df):
        y = df['positive_percentual']
        drop_columns = ['steam_appid', 'name', 'review_score_desc', 'is_released']
        X = df.drop(columns=drop_columns + ['positive_percentual'])
        categorical_features = ['developers', 'publishers', 'categories', 'genres', 'platforms']
        X = pd.get_dummies(X, columns=categorical_features, drop_first=True)
        numerical_features = ['required_age', 'n_achievements', 'total_reviews', 'price_initial (USD)', 'metacritic']
        scaler = StandardScaler()
        X[numerical_features] = scaler.fit_transform(X[numerical_features])
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

        return X_train, X_test, y_train, y_test

    df = load_data()
    x_train, x_test, y_train, y_test = split(df)

    if st.sidebar.checkbox("Show raw data", False):
        st.subheader("Steam Dataset 2025")
        st.write(df)

if __name__ == '__main__':
    main()
